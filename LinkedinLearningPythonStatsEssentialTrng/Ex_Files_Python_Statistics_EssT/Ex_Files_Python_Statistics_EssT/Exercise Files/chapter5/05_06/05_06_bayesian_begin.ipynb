# %% [markdown]
# ## Python statistics essential training - 05_06_bayesian

# %% [markdown]
# Standard imports

# %%
import math

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

# %%
# %matplotlib inline

# %%
# !conda install pymc3
import pymc3 as pm

# %%
n = 100
k = 61

with pm.Model() as coin_context:
    p = pm.Uniform('p', 0.40,0.80)
    
    y = pm.Binomial('y',n=n,p=p,observed=k)
    
    trace = pm.sample(10000)
# Out:
# You can find the C code in this temporary file: C:\Users\charr\AppData\Local\Temp\theano_compilation_error_fn3o_dmu
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7044\1003135623.py in <module>
#       3
#       4 with pm.Model() as coin_context:
# ----> 5     p = pm.Uniform('p', 0.40,0.80)
#       6
#       7     y = pm.Binomial('y',n=n,p=p,observed=k)
#
# ~\anaconda3\lib\site-packages\pymc3\distributions\distribution.py in __new__(cls, name, *args, **kwargs)
#     122             dist = cls.dist(*args, **kwargs, shape=shape)
#     123         else:
# --> 124             dist = cls.dist(*args, **kwargs)
#     125         return model.Var(name, dist, data, total_size, dims=dims)
#     126
#
# ~\anaconda3\lib\site-packages\pymc3\distributions\distribution.py in dist(cls, *args, **kwargs)
#     131     def dist(cls, *args, **kwargs):
# ...

# %%
pm.summary(trace)

# %%
gdata=pd.read_csv('gapminder.csv')

# %%
gdata.sort_values('age5_surviving', inplace=True)

# %%
pp.scatter(gdata['age5_surviving'],gdata['babies_per_woman'])

# %%
with pm.Model() as gapminder_context:
    intercept = pm.Uniform('intercept',5,15)
    slope = pm.Uniform('slope',-1,1)
    
    babies =pm.Normal('babies',mu= intercept + slope * (gdata['age5_surviving'] -65),
                     sd=1,
                     observed=gdata['babies_per_woman'])
    trace = pm.sample(10000)
# Out:
# You can find the C code in this temporary file: C:\Users\charr\AppData\Local\Temp\theano_compilation_error_hhaxj5wh
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7044\1140410365.py in <module>
#       1 with pm.Model() as gapminder_context:
# ----> 2     intercept = pm.Uniform('intercept',5,15)
#       3     slope = pm.Uniform('slope',-1,1)
#       4
#       5     babies =pm.Normal('babies',mu= intercept + slope * (gdata['age5_surviving'] -65),
#
# ~\anaconda3\lib\site-packages\pymc3\distributions\distribution.py in __new__(cls, name, *args, **kwargs)
#     122             dist = cls.dist(*args, **kwargs, shape=shape)
#     123         else:
# --> 124             dist = cls.dist(*args, **kwargs)
#     125         return model.Var(name, dist, data, total_size, dims=dims)
#     126
#
# ...

# %%
pm.summary(trace)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7044\4130194848.py in <module>
# ----> 1 pm.summary(trace)
#
# NameError: name 'trace' is not defined

# %%
pm.traceplot(trace)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7044\4255668653.py in <module>
# ----> 1 pm.traceplot(trace)
#
# NameError: name 'trace' is not defined

# %%
babies = trace['intercept'].mean() + trace['slope'].mean() * (gdata['age5_surviving'] -65)

# %%
pp.scatter(gdata['age5_surviving'],gdata['babies_per_woman'])
pp.plot(gdata['age5_surviving'],babies,'C1')

# %%
pp.scatter(gdata['age5_surviving'],gdata['babies_per_woman'])

for i, intercept,slope in zip(range(100),trace['intercept'][::50],trace['slope'][::50]):
    babies = intercept + slope * (gdata['age5_surviving'] - 65)
    pp.plot(gdata['age5_surviving'],babies,'C1',alpha=0.05)
