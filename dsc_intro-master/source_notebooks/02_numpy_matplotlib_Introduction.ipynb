# %%
m = 5
c = -1
x = [0,1,2,3,4,5,6]

# %%
y = [m*num+c  for num in x]
print(y)
# Out:
# [-1, 4, 9, 14, 19, 24, 29]

# %%
import numpy as np

# %%
X = np.array(x)
Y = m*X + c

# %%
print(Y)
# Out:
# [-1  4  9 14 19 24 29]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X, Y)
plt.plot(X, Y)
plt.show()
